# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sample.csv')
df
# Out:
#      pub_id        topic  disseminationdata     sent_time sub_id  \
# 0       pub      weather              sunny  21-53-56-763    sub
# 1       pub     humidity  82.60566348293766  21-53-56-764    sub
# 2       pub  temperature                 80  21-53-56-764    sub
# 3       pub        light               1100  21-53-56-765    sub
# 4       pub   airquality               smog  21-53-56-766    sub
# ...     ...          ...                ...           ...    ...
# 1188    pub     location               Asia  23-31-27-961    sub
# 1189    pub     pressure                997  23-31-27-963    sub
# 1190    pub     humidity  71.35292545006254  23-31-27-964    sub
# 1191    pub        sound                 36  23-31-27-965    sub
# 1192    pub      weather              rainy  23-31-27-965    sub
#
#      received_time  Num_topics_subscribed  latency  receivedFromBroker
# 0     21-53-56-766                      7      3.0               False
# ...

# %%
df['Num_topics_subscribed'].plot(kind='hist', figsize=(12, 5), bins=9)
plt.title('Num_topics_subscribed and latency for broker approach') # add a title to the histogram
plt.ylabel('Latency') # add y-label
plt.xlabel("Num_topics_subscribed") # add x-label
plt.show()

# %%
sns.distplot(df['Num_topics_subscribed'], bins=9)
# Out:
# /Users/youngjaemoon/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Num_topics_subscribed', ylabel='Density'>

# %%
broker_df = df.loc[df['receivedFromBroker'] == True] 
direct_df = df.loc[df['receivedFromBroker'] == False] 
direct_df
# Out:
#      pub_id        topic  disseminationdata     sent_time sub_id  \
# 0       pub      weather              sunny  21-53-56-763    sub
# 1       pub     humidity  82.60566348293766  21-53-56-764    sub
# 2       pub  temperature                 80  21-53-56-764    sub
# 3       pub        light               1100  21-53-56-765    sub
# 4       pub   airquality               smog  21-53-56-766    sub
# ...     ...          ...                ...           ...    ...
# 1188    pub     location               Asia  23-31-27-961    sub
# 1189    pub     pressure                997  23-31-27-963    sub
# 1190    pub     humidity  71.35292545006254  23-31-27-964    sub
# 1191    pub        sound                 36  23-31-27-965    sub
# 1192    pub      weather              rainy  23-31-27-965    sub
#
#      received_time  Num_topics_subscribed  latency  receivedFromBroker
# 0     21-53-56-766                      7      3.0               False
# ...

# %%
broker_df
# Out:
# Empty DataFrame
# Columns: [pub_id, topic, disseminationdata, sent_time, sub_id, received_time, Num_topics_subscribed, latency, receivedFromBroker]
# Index: []
